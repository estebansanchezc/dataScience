# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import funciones as fx

# %%
conn = fx.conexion_sqlalchemy()

# %%
df = fx.selectView(conn)

# %%
df.head()
# Out:
#                  Clave   Make  make_id          Model  model_id  \
# 0         Acura-TSX4dr  Acura        1         TSX4dr      2392
# 1            Acura-TSX  Acura        1            TSX      2391
# 2         Acura-ILX4dr  Acura        1         ILX4dr      1225
# 3  Acura-ILXAcuraWatch  Acura        1  ILXAcuraWatch      1228
# 4      Acura-ILXHybrid  Acura        1      ILXHybrid      1230
#
#                  Vin  Doors Fuel_Type           Front_Airbag_Location  \
# 0  JH4CU26639C015787      4  gasoline  1st row (driver and passenger)
# 1  JH4C42F48EC000677      0
# 2  19VDE1F34FE007892      4  gasoline  1st row (driver and passenger)
# 3  19UDE2F32HA001240      4  gasoline  1st row (driver and passenger)
# 4  19VDE3F74DE302275      4  gasoline  1st row (driver and passenger)
#
#                      Manufactured  Engine_Displacement_CC  \
# 0            honda motor co., ltd             2359.737216
# 1                                                0.000000
# ...
