# %% [markdown]
# ## Análisis Exploratorio Descriptivo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv('true_car_listings.csv')
df.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %% [markdown]
# ### Gráfico del precio de autos según sus marcas

# %%
plt.figure(figsize = (25,10))
sns.barplot(x='Make', y = 'Price', data = df)
plt.xticks(rotation = 90, fontsize = 15)
plt.yticks(fontsize = 15)
plt.xlabel('Marca', fontsize = 18)
plt.ylabel('Precio', fontsize = 18)
plt.title('\nPrecio de automoviles por marca\n', fontsize = 25);

# %%
df.sort_values(by = 'Price')
# Out:
#          Price  Year  Mileage         City State                Vin  \
# 64965     1500  1998   100296    Levittown    PA  2G4WY52M9W1574802
# 234299    1500  2001   186000         Rome    GA  1B3ES46C41D270207
# 594083    1500  2004   135452   Scottsboro    AL  1YVFP80C645N44861
# 699677    1500  2004   220147    Hillsdale    MI  1G2NW52E54C120668
# 165524    1500  1999   241493      Orlando    FL  1GCCS1949X8152891
# ...        ...   ...      ...          ...   ...                ...
# 549573  462000  2017      261        Davie    FL  ZHWUC1ZD4HLA05825
# 480444  469973  2016     6525     Kirkland    WA  SAJBK4BV2GCY19895
# 549574  469991  2016      312  Saint James    NY  ZHWUR1ZD5GLA05118
# 622264  490000  2008     3307       Encino    CA  WDDAK76F78M001594
# 622265  499500  2014     3260    Westville    NJ  WDDRJ7HA4EA010693
#
#                  Make           Model
# 64965           Buick      Century4dr
# 234299          Dodge         Neon4dr
# 594083          Mazda       Mazda64dr
# 699677        Pontiac           Grand
# 165524      Chevrolet         S-102WD
# ...               ...             ...
# 549573    Lamborghini  AventadorCoupe
# 480444         Jaguar           XF35t
# 549574    Lamborghini    Aventador2dr
# 622264  Mercedes-Benz             SLR
# 622265  Mercedes-Benz             SLS
#
# [852122 rows x 8 columns]

# %%
df['Year'].value_counts()
# Out:
# 2014    162432
# 2015    157516
# 2016    132136
# 2017     91608
# 2013     74701
# 2012     49764
# 2011     39768
# 2010     27539
# 2008     24713
# 2007     21171
# 2009     19061
# 2006     15079
# 2005     11005
# 2004      8117
# 2003      5649
# 2002      3800
# 2001      2584
# 2000      1933
# 1999      1254
# 2018       922
# 1998       774
# 1997       596
# Name: Year, dtype: int64
